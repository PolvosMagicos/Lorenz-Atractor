# %% [markdown]
# # Tarea 1
# Implemente la función representativa del sistema en lenguaje Python.
# Tenga en cuenta que la variable de estado sería un ndArray de 3 dimensiones. Por otra parte, la función recibe los parámetros de entrada
# σ , ρ y β.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
state = [1, 1, 1]

# %%
def lorenz(sigma, beta, ro):
    x, y, z = state
     
    dx = sigma * (y - x)
    dy = x * ro - y - x * z
    dz = x * y - beta * z
     
    return [dx, dy, dz]

# %% [markdown]
# #Tarea 2
# Escriba el código correspondiente a la simulación de este sistema para
# un intervalo de tiempo t ϵ [0; 100] que contenga 3000 valores equidistantes.
# Además utilice los parámetros σ = 10; ρ = 28; β = 8/3 y
# el vector de condiciones iniciales (1; 1; 1). Emplee para ello la función
# odeint.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
def lorenz(state, t, sigma, beta, ro):
    x, y, z = state
     
    dx = sigma * (y - x)
    dy = x * ro - y - x * z
    dz = x * y - beta * z
     
    return [dx, dy, dz]

# %%
sigma = 10
beta = 8 / 3
ro = 28

# %%
def odeintresult(sigma, beta, ro):
    t = np.linspace(0, 100, 3000)
    y0 = [1, 1, 1]
    
    result = odeint(lorenz, y0, t, (sigma, beta, ro))
    
    return result

# %% [markdown]
# #Tarea 3
# Cree una gráfica en 3 dimensiones que utilice la paleta de colores llamada
# plt.cm.plasma para representar la solución la cual debería de tener
# una forma similar a la Figura 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
def lorenz(state, t, sigma, beta, ro):
    x, y, z = state
     
    dx = sigma * (y - x)
    dy = x * ro - y - x * z
    dz = x * y - beta * z
     
    return [dx, dy, dz]

# %%
sigma = 10
beta = 8 / 3
ro = 28

# %%
def odeintresult(sigma, beta, ro):
    t = np.linspace(0, 100, 3000)
    y0 = [1, 1, 1]
    
    result = odeint(lorenz, y0, t, (sigma, beta, ro))
    
    return result

# %%
def plot(array, num, ax = None):
    if ax == None:
        fig = plt.figure()
        fig.set_size_inches(6.5, 10)
        ax = fig.add_subplot(projection="3d")
    
    ax.set_xlabel("Eje X")
    ax.set_ylabel("Eje Y")
    ax.set_zlabel("Eje Z")
    ax.set_title("Atractor de Lorenz")

    for i in range(1,3000):

        ax.plot(array[i-1:i+1, 0], array[i-1:i+1, 1], array[i-1:i+1, 2], c = plt.cm.plasma(1. * i / 3000), lw = 0.5)

    ax.text2D(0.4, 0, f'ρ = {ro}', transform=ax.transAxes)

# %%
array0 = odeintresult(sigma, beta, ro)
plot(array0, ro)

# %% [markdown]
# #Tarea 4
# Solucione el mismo problema con los mismos parámetros a excepción
# de ρ el cual tomará los valores -42, 15, 28 y 100. Almacene las respuestas
# en dos listas, una para el parámetro ρ y la otra para la solución
# correspondiente.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
def lorenz(state, t, sigma, beta, ro):
    x, y, z = state
     
    dx = sigma * (y - x)
    dy = x * ro - y - x * z
    dz = x * y - beta * z
     
    return [dx, dy, dz]

# %%
sigma = 10
beta = 8 / 3

# %%
def odeintresult(sigma, beta, ro):
    t = np.linspace(0, 100, 3000)
    y0 = [1, 1, 1]
    
    result = odeint(lorenz, y0, t, (sigma, beta, ro))
    
    return result

# %%
roList = [-42, 15, 28, 100]
plotList = [odeintresult(sigma, beta, roList[0]), 
            odeintresult(sigma, beta, roList[1]),
            odeintresult(sigma, beta, roList[2]), 
            odeintresult(sigma, beta, roList[3])]

# %% [markdown]
# #Tarea 5
# Cree gráficas de 3 dimensiones para representar cada solución, todas
# en la misma figura. Para ello cree una figura de 2 filas y 2 columnas.
# Coloque en el texto del título de la gráfica el parámetro ρ igualado a
# el valor correspondiente en cada caso. Garantice que la figura tenga
# un tamaño de 10 x 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

# %%
def lorenz(state, t, sigma, beta, ro):
    x, y, z = state
     
    dx = sigma * (y - x)
    dy = x * ro - y - x * z
    dz = x * y - beta * z
     
    return [dx, dy, dz]

# %%
sigma = 10
beta = 8 / 3

# %%
def odeintresult(sigma, beta, ro):
    t = np.linspace(0, 100, 3000)
    y0 = [1, 1, 1]
    
    result = odeint(lorenz, y0, t, (sigma, beta, ro))
    
    return result

# %%
def plot(array, num, ax = None):
    if ax == None:
        fig = plt.figure()
        fig.set_size_inches(6.5, 10)
        ax = fig.add_subplot(projection="3d")
    
    ax.set_xlabel("Eje X")
    ax.set_ylabel("Eje Y")
    ax.set_zlabel("Eje Z")
    ax.set_title("Atractor de Lorenz")

    for i in range(1,3000):

        ax.plot(array[i-1:i+1, 0], array[i-1:i+1, 1], array[i-1:i+1, 2], c = plt.cm.plasma(1. * i / 3000), lw = 0.5)

    ax.text2D(0.38, -0.015, f'ρ = {ro}', transform=ax.transAxes)

# %%
roList = [-42, 15, 28, 100]
plotList = [odeintresult(sigma, beta, roList[0]), 
            odeintresult(sigma, beta, roList[1]),
            odeintresult(sigma, beta, roList[2]), 
            odeintresult(sigma, beta, roList[3])]

# %%
rows, cols = 2, 2
fig, axs = plt.subplots(2, 2, figsize=(10,10), subplot_kw=dict(projection='3d'))
plt.tight_layout(h_pad=3)


for ax, ro in zip(axs.flatten(), roList):
  plot(odeintresult(sigma, beta, ro), ro, ax = ax)
